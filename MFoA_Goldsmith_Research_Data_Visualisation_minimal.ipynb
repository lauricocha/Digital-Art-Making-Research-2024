# %%
import seaborn as sns
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
# %%capture
pip install pandas scipy

# %%
# %%capture
pip install -U kaleido

# %%
# %%capture
pip install --upgrade seaborn

# %%
import seaborn as sns
print(sns.__version__)
# Out:
# 0.13.2

# %% [markdown]
# <div style="background-color: #ffbf69; padding: 10px; border-radius: 5px;">
#     <h1 style="font-size: 44px; color: #4b2f25;">Initial Data Validation</h1>
# </div>

# %% [markdown]
# <div style="margin-top: -10px;">
# <h3 style="font-size: 14px;">The data for this analysis has been sourced from three distinct CSV files. Each file contains relevant information, which has been restructured and integrated. The configuration process involved aligning data formats, ensuring consistency across datasets, and combining key variables.</h3>
# </div>

# %% [markdown]
# <div style="margin-top: -10px; background-color: #cbf3f0; padding: 10px; border-radius: 5px;">
# <h2 style="font-size: 24px; color: #2ec4b6;">MFoA data</h2>
# </div>

# %% [markdown]
# <div style="margin-top: -10px;">
# <h3 style="font-size: 14px;">This first dataset contains all data collected with a survey sent at the beginning and end of the study using the Qualtrics platform.</h3>
# </div>

# %%
url = 'https://raw.githubusercontent.com/lauricocha/Digital-Art-Making-Research-2024/main/MFoA-data-LG.csv'
MFOA = pd.read_csv(url)

# %%
MFOA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     17 non-null     object
#  1   Age                    17 non-null     int64
#  2   Gender                 17 non-null     object
#  3   Ethnicity ID           17 non-null     object
#  4   VAIAK                  17 non-null     int64
#  5   SSCS                   17 non-null     int64
#  6   Initial_Anxiety_level  17 non-null     object
#  7   STAI-T0                17 non-null     int64
#  8   STAI-T1                17 non-null     int64
#  9   Final_Anxiety_Level    17 non-null     object
#  10  STAI-change            17 non-null     int64
#  11  Last_Recorded_STAI     17 non-null     int64
#  12  Weeks_done             17 non-null     object
#  13  Weeks_Completed        17 non-null     int64
# ...

# %%
MFOA.head(22)
# Out:
#             ID  Age             Gender Ethnicity ID  VAIAK  SSCS  \
# 0   AMF1970039   52             Female      HispLat     53    39
# 1   BNF2002007   20             Female        Asian     37    36
# 2   LVF1995046   28             Female        Mixed     39    31
# 3   CDF1998025   24             Female        White     21    23
# 4   CEM1994045   28               Male        White     25    31
# 5   EVM1965040   57               Male        White     45    38
# 6   VVR2003016   19  Prefer not to say      HispLat     33    42
# 7   HKF1990010   32             Female        Asian     44    42
# 8   SVM1997033   25               Male      HispLat     20    44
# 9   SHF1961006   61             Female        Other     42    37
# 10  CCF1950049   72             Female        White     41    35
# 11  ROF1972041   51             Female        White     30    28
# 12  akF1992022   31             Female        White     44    31
# ...

# %%
MFOA.describe()
# Out:
#              Age      VAIAK       SSCS    STAI-T0    STAI-T1  STAI-change  \
# count  17.000000  17.000000  17.000000  17.000000  17.000000    17.000000
# mean   36.764706  39.764706  35.529412  41.941176  37.705882    -4.235294
# std    16.835711  10.946058   5.467148  14.033311  11.623063     7.250254
# min    19.000000  20.000000  23.000000  24.000000  23.000000   -18.000000
# 25%    24.000000  33.000000  31.000000  29.000000  26.000000   -10.000000
# 50%    28.000000  42.000000  37.000000  40.000000  36.000000    -3.000000
# 75%    52.000000  45.000000  39.000000  52.000000  47.000000     0.000000
# max    72.000000  55.000000  44.000000  72.000000  60.000000     8.000000
#
#        Last_Recorded_STAI  Weeks_Completed     Liking  Application
# count           17.000000        17.000000  16.000000    16.000000
# mean            37.705882         4.352941   7.937500     7.250000
# std             11.623063         3.408467   1.806239     2.744692
# ...

# %%
MFOA.isna()
# Out:
#        ID    Age  Gender  Ethnicity ID  VAIAK   SSCS  Initial_Anxiety_level  \
# 0   False  False   False         False  False  False                  False
# 1   False  False   False         False  False  False                  False
# 2   False  False   False         False  False  False                  False
# 3   False  False   False         False  False  False                  False
# 4   False  False   False         False  False  False                  False
# 5   False  False   False         False  False  False                  False
# 6   False  False   False         False  False  False                  False
# 7   False  False   False         False  False  False                  False
# 8   False  False   False         False  False  False                  False
# 9   False  False   False         False  False  False                  False
# 10  False  False   False         False  False  False                  False
# ...

# %%
MFOA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     17 non-null     object
#  1   Age                    17 non-null     int64
#  2   Gender                 17 non-null     object
#  3   Ethnicity ID           17 non-null     object
#  4   VAIAK                  17 non-null     int64
#  5   SSCS                   17 non-null     int64
#  6   Initial_Anxiety_level  17 non-null     object
#  7   STAI-T0                17 non-null     int64
#  8   STAI-T1                17 non-null     int64
#  9   Final_Anxiety_Level    17 non-null     object
#  10  STAI-change            17 non-null     int64
#  11  Last_Recorded_STAI     17 non-null     int64
#  12  Weeks_done             17 non-null     object
#  13  Weeks_Completed        17 non-null     int64
# ...

# %% [markdown]
# <div style="margin-top: -10px; background-color: #cbf3f0; padding: 10px; border-radius: 5px;">
# <h2 style="font-size: 24px; color: #2ec4b6;">MFoA data weekly</h2>
# </div>

# %% [markdown]
# <div style="margin-top: -10px;">
# <h3 style="font-size: 14px;">The second dataset includes all weekly self-assessment scores on STAI, Flow, Arousal, and Positivity for each participant.</h3>
# </div>

# %%
url2 = 'https://raw.githubusercontent.com/lauricocha/Digital-Art-Making-Research-2024/main/MFoA-data-weekly-LG.csv'
Weekly = pd.read_csv(url2)

# %%
Weekly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Week_number  96 non-null     float64
#  1   ID           96 non-null     object
#  2   STAI         96 non-null     int64
#  3   FLOW         96 non-null     int64
#  4   Arousal      96 non-null     int64
#  5   Positivity   96 non-null     int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 4.6+ KB

# %%
Weekly.head(23)
# Out:
#     Week_number          ID  STAI  FLOW  Arousal  Positivity
# 0           0.0  AMF1970039    29     0        0           0
# 1           1.0  AMF1970039    28    44        5           9
# 2           2.0  AMF1970039    27    42        7           9
# 3           3.0  AMF1970039    33    40        3           9
# 4           4.0  AMF1970039    26    43        3           9
# 5           5.0  AMF1970039    24    44        4           9
# 6           6.0  AMF1970039    26    45        3           9
# 7           7.0  AMF1970039    34    32        4           7
# 8           8.0  AMF1970039    26    39        5           9
# 9           8.1  AMF1970039    37     0        0           0
# 10          0.0  BNF2002007    25     0        0           0
# 11          1.0  BNF2002007    23    33        4           7
# 12          2.0  BNF2002007    41    35        3           2
# 13          3.0  BNF2002007    23    34        3           9
# ...

# %%
Weekly.describe()
# Out:
#        Week_number       STAI       FLOW    Arousal  Positivity
# count    96.000000  96.000000  96.000000  96.000000   96.000000
# mean      4.022917  33.781250  26.604167   3.020833    5.052083
# std       2.848212  10.669389  16.396713   2.370783    3.425507
# min       0.000000  20.000000   0.000000   0.000000    0.000000
# 25%       1.750000  26.000000  12.750000   0.750000    0.750000
# 50%       4.000000  31.500000  33.000000   3.000000    7.000000
# 75%       7.000000  40.000000  39.000000   4.000000    8.000000
# max       8.100000  72.000000  45.000000   9.000000    9.000000

# %%
Weekly.isna()
# Out:
#     Week_number     ID   STAI   FLOW  Arousal  Positivity
# 0         False  False  False  False    False       False
# 1         False  False  False  False    False       False
# 2         False  False  False  False    False       False
# 3         False  False  False  False    False       False
# 4         False  False  False  False    False       False
# ..          ...    ...    ...    ...      ...         ...
# 91        False  False  False  False    False       False
# 92        False  False  False  False    False       False
# 93        False  False  False  False    False       False
# 94        False  False  False  False    False       False
# 95        False  False  False  False    False       False
#
# [96 rows x 6 columns]

# %% [markdown]
# <div style="margin-top: -10px; background-color: #cbf3f0; padding: 10px; border-radius: 5px;">
# <h2 style="font-size: 24px; color: #2ec4b6;">MFoA data Pre-Post Intervention</h2>
# </div>

# %% [markdown]
# <div style="margin-top: -10px;">
# <h3 style="font-size: 14px;">This third dataset shows the pre- and post-intervention data of participants who completed at least one digital art session.</h3>
# </div>

# %%
url3 = 'https://raw.githubusercontent.com/lauricocha/Digital-Art-Making-Research-2024/main/MFoA-data-pre-post-intervention-LG.csv'
WeeklyV2 = pd.read_csv(url3)

# %%
WeeklyV2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 14 non-null     object
#  1   Initial_STAI       14 non-null     int64
#  2   Pre_Intervention   14 non-null     int64
#  3   Final_STAI         14 non-null     int64
#  4   Post_Intervention  14 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 692.0+ bytes

# %%
WeeklyV2.head(22)
# Out:
#             ID  Initial_STAI  Pre_Intervention  Final_STAI  Post_Intervention
# 0   AMF1970039            29                 1          37                  1
# 1   BNF2002007            25                 1          23                  1
# 2   CDF1998025            52                 3          47                  3
# 3   CEM1994045            72                 3          60                  3
# 4   EVM1965040            52                 3          34                  1
# 5   LVF1995046            40                 2          40                  2
# 6   VVR2003016            34                 1          26                  1
# 7   HKF1990010            27                 1          32                  1
# 8   SVM1997033            56                 3          46                  3
# 9   SHF1961006            29                 1          26                  1
# 10  CCF1950049            24                 1          25                  1
# ...

# %%
WeeklyV2.describe()
# Out:
#        Initial_STAI  Pre_Intervention  Final_STAI  Post_Intervention
# count     14.000000         14.000000   14.000000           14.00000
# mean      39.428571          1.785714   34.785714            1.50000
# std       14.080616          0.892582   10.598828            0.85485
# min       24.000000          1.000000   23.000000            1.00000
# 25%       29.000000          1.000000   26.000000            1.00000
# 50%       36.500000          1.500000   33.000000            1.00000
# 75%       49.500000          2.750000   39.250000            1.75000
# max       72.000000          3.000000   60.000000            3.00000

# %%
WeeklyV2.isna()
# Out:
#        ID  Initial_STAI  Pre_Intervention  Final_STAI  Post_Intervention
# 0   False         False             False       False              False
# 1   False         False             False       False              False
# 2   False         False             False       False              False
# 3   False         False             False       False              False
# 4   False         False             False       False              False
# 5   False         False             False       False              False
# 6   False         False             False       False              False
# 7   False         False             False       False              False
# 8   False         False             False       False              False
# 9   False         False             False       False              False
# 10  False         False             False       False              False
# 11  False         False             False       False              False
# ...

# %% [markdown]
# <div style="background-color: #ffbf69; padding: 10px; border-radius: 5px;">
#     <h1 style="font-size: 44px; color: #4b2f25;">Assessing VAIAK and SSCS influence on STAI trends</h1>
# </div>

# %% [markdown]
# <div style="margin-top: -10px; background-color: #cbf3f0; padding: 10px; border-radius: 5px;">
# <h2 style="font-size: 24px; color: #2ec4b6;">Scatter plots to illustrate the relationship between VAIAK scores and change in STAI level</h2>
# </div>

# %%
import plotly.express as px
import pandas as pd
import plotly.io as pio
from IPython.display import Image

# Read the CSV file
url = 'https://raw.githubusercontent.com/lauricocha/Digital-Art-Making-Research-2024/main/MFoA-data-LG.csv'
df = pd.read_csv(url)

# Create a scatter plot
fig = px.scatter(df, x="VAIAK", y="STAI-T0", color="Initial_Anxiety_level",
                 size='STAI-T0', hover_data=['VAIAK'])

# Update the y-axis range
fig.update_yaxes(range=[15, 80])

# Update layout
fig.update_layout(
    height=600, 
    width=490, 
    showlegend=False,
    title=dict(
        text="Initial STAI score",
        x=0.5,  # Center the title horizontally
        xanchor='center',
        yanchor='top'
    ),
    title_font=dict(size=22)
)

# Save the figure as a static image
pio.write_image(fig, "plotly_figure.png")

# Display the static image
Image("plotly_figure.png")

# %%
import plotly.express as px
import pandas as pd
import plotly.io as pio
from IPython.display import Image

# Read the CSV file
url = 'https://raw.githubusercontent.com/lauricocha/Digital-Art-Making-Research-2024/main/MFoA-data-LG.csv'
df = pd.read_csv(url)

# Create a scatter plot
fig = px.scatter(df, x="VAIAK", y="Last_Recorded_STAI", color="Final_Anxiety_Level",
                 size='Last_Recorded_STAI', hover_data=['VAIAK'])

# Update the y-axis range
fig.update_yaxes(range=[15, 80])

# Update layout
fig.update_layout(
    height=600, 
    width=630, 
    showlegend=True,
    title=dict(
        text="Final STAI score",
        x=0.4,  # Center the title horizontally
        xanchor='center',
        yanchor='top'
    ),
    title_font=dict(size=22)
)

# Save the figure as a static image using kaleido
pio.write_image(fig, "plotly_figure_final.png")

# Display the static image
display(Image("plotly_figure_final.png"))

# %% [markdown]
# <div style="margin-top: -10px; background-color: #cbf3f0; padding: 10px; border-radius: 5px;">
# <h2 style="font-size: 24px; color: #2ec4b6;">Scatter plots to illustrate the relationship betweenSSCSK scores and change in STAI level</h2>
# </div>

# %%
import plotly.express as px
import pandas as pd
import plotly.io as pio
from IPython.display import Image

# Read the CSV file
url = 'https://raw.githubusercontent.com/lauricocha/Digital-Art-Making-Research-2024/main/MFoA-data-LG.csv'
df = pd.read_csv(url)

# Create a scatter plot
fig = px.scatter(df, x="SSCS", y="STAI-T0", color="Initial_Anxiety_level",
                 size='STAI-T0', hover_data=['SSCS'])

# Update layout
fig.update_layout(
    height=600, 
    width=490, 
    showlegend=False,
    title=dict(
        text="Initial STAI score",
        x=0.5,  # Center the title horizontally
        xanchor='center',
        yanchor='top'
    ),
    title_font=dict(size=22)
)

# Save the figure as a static image using kaleido
pio.write_image(fig, "plotly_figure_initial.png")

# Display the static image
display(Image("plotly_figure_initial.png"))

# %%
import plotly.express as px
import pandas as pd
import plotly.io as pio
from IPython.display import Image

# Read the CSV file
url = 'https://raw.githubusercontent.com/lauricocha/Digital-Art-Making-Research-2024/main/MFoA-data-LG.csv'
df = pd.read_csv(url)

# Create a scatter plot
fig = px.scatter(df, x="SSCS", y="Last_Recorded_STAI", color="Final_Anxiety_Level",
                 size='Last_Recorded_STAI', hover_data=['SSCS'])

# Update the y-axis range
fig.update_yaxes(range=[15, 80])

# Update layout
fig.update_layout(
    height=600, 
    width=630, 
    showlegend=True,
    title=dict(
        text="Final STAI score",
        x=0.4,  # Center the title horizontally
        xanchor='center',
        yanchor='top'
    ),
    title_font=dict(size=22)
)

# Save the figure as a static image using kaleido
pio.write_image(fig, "plotly_figure_final_stai.png")

# Display the static image
display(Image("plotly_figure_final_stai.png"))

# %%
columns_to_drop = ['Age', 'STAI-T0', 'STAI-T1', 'Liking', 'Application', 'Gender', 'Ethnicity ID', 'Weeks_Completed', 'ID', 'Final_Anxiety_Level', 'Last_Recorded_STAI', 'Initial_Anxiety_level', 'Weeks_done']  # Replace with the actual column names
Artsy = MFOA.drop(columns_to_drop, axis=1)

Artsy
# Out:
#     VAIAK  SSCS  STAI-change
# 0      53    39            8
# 1      37    36           -2
# 2      39    31            0
# 3      21    23           -5
# 4      25    31          -12
# 5      45    38          -18
# 6      33    42           -8
# 7      44    42            5
# 8      20    44          -10
# 9      42    37           -3
# 10     41    35            1
# 11     30    28           -6
# 12     44    31          -12
# 13     42    38          -12
# 14     53    39           -2
# 15     52    37           -3
# 16     55    33            7

# %% [markdown]
# <div style="margin-top: -10px; background-color: #cbf3f0; padding: 10px; border-radius: 5px;">
# <h2 style="font-size: 24px; color: #2ec4b6;">Comparison of VAIAK, SSCS, and STAI using Correlation Coefficients and P-values</h2>
# </div>

# %%
Artsy.corr()
# Out:
#                 VAIAK      SSCS  STAI-change
# VAIAK        1.000000  0.278974     0.456816
# SSCS         0.278974  1.000000     0.049065
# STAI-change  0.456816  0.049065     1.000000

# %% [markdown]
# ## Heatmap of Correlation Coefficients: VAIAK, SSCS, and STAI

# %%
corr = Artsy.corr().round(2)

# plot the heatmap
plt.figure(figsize = (8,6))

#viz the heatmap
sns.heatmap(corr, annot= True)
# Out:
# <Axes: >

# %% [markdown]
# ## P-Value Heatmap for Correlation Analysis: VAIAK, SSCS, and STAI

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats

# Calculate the correlation coefficients
correlation_matrix = Artsy.corr()

# Calculate the p-values
p_values = Artsy.apply(lambda x: Artsy.apply(lambda y: stats.pearsonr(x, y)[1]))

# Create a heatmap of the p-values
pvalue_heatmap = sns.heatmap(p_values, annot=True, cmap='rocket', fmt='.2f')

# %% [markdown]
# <div style="background-color: #ffbf69; padding: 10px; border-radius: 5px;">
#     <h1 style="font-size: 44px; color: #4b2f25;">Effect of intervention on anxiety reduction over weeks completed</h1>
# </div>

# %%
import plotly.graph_objects as go
import pandas as pd
import plotly.io as pio
from IPython.display import Image

# Read the CSV file
url = 'https://raw.githubusercontent.com/lauricocha/Digital-Art-Making-Research-2024/main/MFoA-data-LG.csv'
df = pd.read_csv(url)

fig = go.Figure()

Weeks_done = ['8 wks', '5-4 wks', '3-2 wks', '1 wk', '0 wks']

for week in Weeks_done:
    fig.add_trace(go.Violin(x=df['Weeks_done'][df['Weeks_done'] == week],
                            y=df['STAI-change'][df['Weeks_done'] == week],
                            name=week,
                            box_visible=True,
                            meanline_visible=True))
    
fig.update_layout(
    title="Effect of Intervention on Anxiety Reduction<br>Over Weeks Completed",
    title_font=dict(size=22)
)

fig.add_annotation(
    text="Chi-squared statistic: 74.14<br>p-value: 0.40828<br>Degrees of freedom: 72",
    x=2,  # Adjust the x and y values for proper positioning
    y=-24,
    showarrow=False,
    font=dict(size=16)  # Adjust the font size as needed
)

# Save the figure as a static image using kaleido
pio.write_image(fig, "plotly_figure_violin.png")

# Display the static image
display(Image("plotly_figure_violin.png"))

# %%
url = 'https://raw.githubusercontent.com/lauricocha/Digital-Art-Making-Research-2024/main/MFoA-data-LG.csv' 
MFOA = pd.read_csv(url)

correlation = MFOA['Weeks_Completed'].corr(MFOA['STAI-change'])

# %%
# Check the correlation
if correlation == 0:
    print("There is no linear correlation between the two columns.")
else:
    print(f"There is a correlation of {correlation:.2f} between the two columns.")
# Out:
# There is a correlation of -0.08 between the two columns.

# %%
from scipy.stats import pearsonr
correlation, p_value = pearsonr(MFOA['Weeks_Completed'], MFOA['STAI-change'])

# %%
correlation_coefficient, p_value = pearsonr(MFOA['Weeks_Completed'], MFOA['STAI-change'])

# Output the results
print(f"Pearson correlation coefficient (r): {correlation_coefficient}")
print(f"P-value: {p_value}")
# Out:
# Pearson correlation coefficient (r): -0.07989012451211118
# P-value: 0.7605240113784817

# %%
contingency_table = pd.crosstab(MFOA['Weeks_Completed'], MFOA['STAI-change'])

# %%
from scipy.stats import chi2_contingency

chi2, p, dof, expected = chi2_contingency(contingency_table)

# Output the results
print(f"Chi-squared statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of freedom: {dof}")
print("Expected frequencies:")
print(expected)
# Out:
# Chi-squared statistic: 74.13888888888887
# P-value: 0.4082837342047034
# Degrees of freedom: 72
# Expected frequencies:
# [[0.17647059 0.52941176 0.17647059 0.17647059 0.17647059 0.17647059
#   0.35294118 0.35294118 0.17647059 0.17647059 0.17647059 0.17647059
#   0.17647059]
#  [0.11764706 0.35294118 0.11764706 0.11764706 0.11764706 0.11764706
#   0.23529412 0.23529412 0.11764706 0.11764706 0.11764706 0.11764706
#   0.11764706]
#  [0.11764706 0.35294118 0.11764706 0.11764706 0.11764706 0.11764706
#   0.23529412 0.23529412 0.11764706 0.11764706 0.11764706 0.11764706
#   0.11764706]
#  [0.05882353 0.17647059 0.05882353 0.05882353 0.05882353 0.05882353
#   0.11764706 0.11764706 0.05882353 0.05882353 0.05882353 0.05882353
#   0.05882353]
#  [0.05882353 0.17647059 0.05882353 0.05882353 0.05882353 0.05882353
#   0.11764706 0.11764706 0.05882353 0.05882353 0.05882353 0.05882353
#   0.05882353]
#  [0.05882353 0.17647059 0.05882353 0.05882353 0.05882353 0.05882353
# ...

# %%
cols = ['Initial_Anxiety_level','STAI-change','Weeks_done']
ComValue = df[cols]

# %%
ComValue
# Out:
#    Initial_Anxiety_level  STAI-change Weeks_done
# 0            low_anxiety            8      8 wks
# 1            low_anxiety           -2      8 wks
# 2       moderate_anxiety            0      8 wks
# 3           high_anxiety           -5      8 wks
# 4           high_anxiety          -12      8 wks
# 5           high_anxiety          -18      8 wks
# 6            low_anxiety           -8      8 wks
# 7            low_anxiety            5    5-4 wks
# 8           high_anxiety          -10    5-4 wks
# 9            low_anxiety           -3    3-2 wks
# 10           low_anxiety            1    3-2 wks
# 11           low_anxiety           -6    3-2 wks
# 12          high_anxiety          -12      0 wks
# 13      moderate_anxiety          -12       1 wk
# 14          high_anxiety           -2      0 wks
# 15      moderate_anxiety           -3       1 wk
# 16          high_anxiety            7      0 wks

# %%
df2 = ComValue.loc[(df['Weeks_done'] !='Zero')]
df2
# Out:
#    Initial_Anxiety_level  STAI-change Weeks_done
# 0            low_anxiety            8      8 wks
# 1            low_anxiety           -2      8 wks
# 2       moderate_anxiety            0      8 wks
# 3           high_anxiety           -5      8 wks
# 4           high_anxiety          -12      8 wks
# 5           high_anxiety          -18      8 wks
# 6            low_anxiety           -8      8 wks
# 7            low_anxiety            5    5-4 wks
# 8           high_anxiety          -10    5-4 wks
# 9            low_anxiety           -3    3-2 wks
# 10           low_anxiety            1    3-2 wks
# 11           low_anxiety           -6    3-2 wks
# 12          high_anxiety          -12      0 wks
# 13      moderate_anxiety          -12       1 wk
# 14          high_anxiety           -2      0 wks
# 15      moderate_anxiety           -3       1 wk
# 16          high_anxiety            7      0 wks

# %%
columns_to_drop = ['Age', 'STAI-T0', 'STAI-T1', 'Liking', 'Application', 'Gender', 'Ethnicity ID', 'Weeks_done','VAIAK', 'SSCS', 'Final_Anxiety_Level', 'Last_Recorded_STAI', 'ID', 'Initial_Anxiety_level']  # Replace with the actual column names
Anxiety = MFOA.drop(columns_to_drop, axis=1)

Anxiety
# Out:
#     STAI-change  Weeks_Completed
# 0             8                8
# 1            -2                8
# 2             0                8
# 3            -5                8
# 4           -12                8
# 5           -18                8
# 6            -8                8
# 7             5                5
# 8           -10                4
# 9            -3                3
# 10            1                2
# 11           -6                2
# 12          -12                0
# 13          -12                1
# 14           -2                0
# 15           -3                1
# 16            7                0

# %%
Anxiety.corr()
# Out:
#                  STAI-change  Weeks_Completed
# STAI-change          1.00000         -0.07989
# Weeks_Completed     -0.07989          1.00000

# %%
corr = Anxiety.corr().round(2)

# plot the heatmap
plt.figure(figsize = (8,6))

#viz the heatmap
sns.heatmap(corr, annot= True)
# Out:
# <Axes: >

# %% [markdown]
# <div style="background-color: #ffbf69; padding: 10px; border-radius: 5px;">
#     <h1 style="font-size: 44px; color: #4b2f25;">Effect of intervention on lowering anxiety across various initial anxiety levels</h1>
# </div>

# %%
import plotly.graph_objects as go
import pandas as pd
import plotly.io as pio
from IPython.display import Image

# Read the CSV file
url = 'https://raw.githubusercontent.com/lauricocha/Digital-Art-Making-Research-2024/main/MFoA-data-LG.csv'
df = pd.read_csv(url)

fig = go.Figure()

Anxiety_levels = ['low_anxiety', 'moderate_anxiety', 'high_anxiety']

for level in Anxiety_levels:
    fig.add_trace(go.Violin(x=df['Initial_Anxiety_level'][df['Initial_Anxiety_level'] == level],
                            y=df['STAI-change'][df['Initial_Anxiety_level'] == level],
                            name=level,
                            box_visible=True,
                            meanline_visible=True))
    
fig.update_layout(
    title="Effect of Intervention on Lowering Anxiety<br>Across Various Initial Anxiety Levels",
    title_font=dict(size=22)
)

fig.add_annotation(
    text="Chi-squared statistic: 13.18<br>p-value: 0.01041<br>Degrees of freedom: 4",
    x=0.2,  # Adjust the x and y values for proper positioning
    y=-22,
    showarrow=False,
    font=dict(size=16)  # Adjust the font size as needed
)

# Save the figure as a static image using kaleido
pio.write_image(fig, "plotly_figure_anxiety_levels.png")

# Display the static image
display(Image("plotly_figure_anxiety_levels.png"))

# %%
contingency_table = pd.crosstab(WeeklyV2['Pre_Intervention'], WeeklyV2['Post_Intervention'])

# %%
from scipy.stats import chi2_contingency

chi2, p, dof, expected = chi2_contingency(contingency_table)

# Output the results Figure 4B
print(f"Chi-squared statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of freedom: {dof}")
print("Expected frequencies:")
print(expected)
# Out:
# Chi-squared statistic: 13.183333333333334
# P-value: 0.01041388244798002
# Degrees of freedom: 4
# Expected frequencies:
# [[5.         0.5        1.5       ]
#  [2.14285714 0.21428571 0.64285714]
#  [2.85714286 0.28571429 0.85714286]]

# %%
from scipy.stats import pearsonr
correlation, p_value = pearsonr(WeeklyV2['Pre_Intervention'], WeeklyV2['Post_Intervention'])

# %%
correlation_coefficient, p_value = pearsonr(WeeklyV2['Pre_Intervention'], WeeklyV2['Post_Intervention'])

# Output the results Figure 4B
print(f"Pearson correlation coefficient (r): {correlation_coefficient}")
print(f"P-value: {p_value}")
# Out:
# Pearson correlation coefficient (r): 0.7561004168034701
# P-value: 0.0017549951966971905

# %% [markdown]
# <div style="background-color: #ffbf69; padding: 10px; border-radius: 5px;">
#     <h1 style="font-size: 44px; color: #4b2f25;">Digital Art Making Weekly Task Results</h1>
# </div>

# %%
columns_to_drop = ['ID']  # Replace with the actual column names
STAI = Weekly.drop(columns_to_drop, axis=1)

STAI
# Out:
#     Week_number  STAI  FLOW  Arousal  Positivity
# 0           0.0    29     0        0           0
# 1           1.0    28    44        5           9
# 2           2.0    27    42        7           9
# 3           3.0    33    40        3           9
# 4           4.0    26    43        3           9
# ..          ...   ...   ...      ...         ...
# 91          8.1    25     0        0           0
# 92          0.0    31     0        0           0
# 93          1.0    44    27        7           5
# 94          2.0    47    35        5           6
# 95          8.1    25     0        0           0
#
# [96 rows x 5 columns]

# %%
STAI.corr()
# Out:
#              Week_number      STAI      FLOW   Arousal  Positivity
# Week_number     1.000000 -0.207563  0.042030  0.008346    0.003113
# STAI           -0.207563  1.000000 -0.327524 -0.043513   -0.472602
# FLOW            0.042030 -0.327524  1.000000  0.671495    0.913811
# Arousal         0.008346 -0.043513  0.671495  1.000000    0.605173
# Positivity      0.003113 -0.472602  0.913811  0.605173    1.000000

# %%
corr = STAI.corr().round(2)

# plot the heatmap
plt.figure(figsize = (15,10))

#viz the heatmap
sns.heatmap(corr, annot= True)
# Out:
# <Axes: >

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats

# Calculate the correlation coefficients
correlation_matrix = STAI.corr()

# Calculate the p-values
p_values = STAI.apply(lambda x: STAI.apply(lambda y: stats.pearsonr(x, y)[1]))

# Create a heatmap of the p-values
pvalue_heatmap = sns.heatmap(p_values, annot=True, cmap='rocket', fmt='.2f')

# %%
pvalue_heatmap.figure.savefig('heatmap.png', format='png', dpi=300, bbox_inches='tight')

# %%
# Define a custom color palette (you can replace these with your desired colors)
custom_palette = ["#7c1c5b"]

# Set the custom color palette
sns.set_palette(custom_palette)
ax = corr['Week_number'].sort_values()[:-1].plot(kind = 'bar', figsize = (10,6))
ax.set_title('Spearman Correlation of Weekly Survey Results', loc='left', y=1.05)

ax.bar_label(ax.containers[0]);

# %%
url2 = 'https://raw.githubusercontent.com/lauricocha/Digital-Art-Making-Research-2024/main/MFoA-data-weekly-LG.csv'
df4 = pd.read_csv(url2)


# Check for NaN values
print("NaN values:\n", df4.isnull().sum())
# Out:
# NaN values:
#  Week_number    0
# ID             0
# STAI           0
# FLOW           0
# Arousal        0
# Positivity     0
# dtype: int64

# %%
# Check data types of each column
print("Data Types:\n", df4.dtypes)
# Out:
# Data Types:
#  Week_number    float64
# ID              object
# STAI             int64
# FLOW             int64
# Arousal          int64
# Positivity       int64
# dtype: object

# %%
# Convert data types of numeric columns to float64
numeric_columns = ['STAI', 'FLOW', 'Arousal', 'Positivity']
df4[numeric_columns] = df4[numeric_columns].astype(float)

# Check data types after conversion
print("Updated Data Types:\n", df4.dtypes)

# Handle non-numeric values (e.g., convert 'inf' values to NaN)
df4.replace([np.inf, -np.inf], np.nan, inplace=True)

# Apply np.isinf() only to numeric columns
inf_values = df4[numeric_columns].apply(lambda x: np.isinf(x)).sum()

# Print the number of infinity values in each column
print("Inf values after dropping:\n", inf_values)
# Out:
# Updated Data Types:
#  Week_number    float64
# ID              object
# STAI           float64
# FLOW           float64
# Arousal        float64
# Positivity     float64
# dtype: object
# Inf values after dropping:
#  STAI          0
# FLOW          0
# Arousal       0
# Positivity    0
# dtype: int64

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Assuming 'df' is your DataFrame containing the data
# 'dependent_variable' is the name of your dependent variable column
# 'independent_variables' is a list of names of your independent variables
# 'data' is the DataFrame containing your data

# Construct the formula string
formula = 'STAI ~ ' + ' + '.join(['ID', 'Week_number'])

# Fit the model
model = ols(formula, data=df4).fit()

# Perform ANOVA
anova_table = sm.stats.anova_lm(model, typ=3)

# Print the ANOVA table with Type III sum of squares
print(anova_table)
# Out:
#                   sum_sq    df           F        PR(>F)
# Intercept    8363.505439   1.0  122.244651  5.403423e-18
# ID           4669.957236  11.0    6.205285  2.360932e-07
# Week_number   471.209182   1.0    6.887399  1.033019e-02
# Residual     5678.538437  83.0         NaN           NaN

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Assuming 'df' is your DataFrame containing the data
# 'dependent_variable' is the name of your dependent variable column
# 'independent_variables' is a list of names of your independent variables
# 'data' is the DataFrame containing your data

# Construct the formula string
formula = 'STAI ~ ' + ' + '.join(['ID', 'Week_number'])

# Fit the model
model = ols(formula, data=df4).fit()

# Perform ANOVA
anova_table = sm.stats.anova_lm(model, typ=1)

# Print the ANOVA table with Type I sum of squares
print(anova_table)
# Out:
#                df       sum_sq     mean_sq         F        PR(>F)
# ID           11.0  4664.658631  424.059876  6.198245  2.405270e-07
# Week_number   1.0   471.209182  471.209182  6.887399  1.033019e-02
# Residual     83.0  5678.538437   68.416126       NaN           NaN

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

# Fit the OLS model
model = ols('STAI ~ C(ID, Sum) * C(Week_number, Sum)', data=df4).fit()

# Perform the ANOVA
anova_results = anova_lm(model, typ=2)

print(anova_results)
# Out:
# C:\Users\laptop\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1716: RuntimeWarning:
#
# divide by zero encountered in scalar divide
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 9
#       6 model = ols('STAI ~ C(ID, Sum) * C(Week_number, Sum)', data=df4).fit()
#       8 # Perform the ANOVA
# ----> 9 anova_results = anova_lm(model, typ=2)
#      11 print(anova_results)
#
# File ~\anaconda3\Lib\site-packages\statsmodels\stats\anova.py:349, in anova_lm(*args, **kwargs)
#     347 if len(args) == 1:
#     348     model = args[0]
# --> 349     return anova_single(model, **kwargs)
#     351 if typ not in [1, "I"]:
#     352     raise ValueError("Multiple models only supported for type I. "
#     353                      "Got type %s" % str(typ))
#
# ...

# %% [markdown]
# <div style="background-color: #ffbf69; padding: 10px; border-radius: 5px;">
#     <h1 style="font-size: 44px; color: #4b2f25;">Additional Data Analysis</h1>
# </div>

# %% [markdown]
# <div style="margin-top: -10px; background-color: #cbf3f0; padding: 10px; border-radius: 5px;">
# <h2 style="font-size: 24px; color: #2ec4b6;">VAIAK further analysis</h2>
# </div>

# %%
cols = ['VAIAK','STAI-change','Weeks_done']
ComValue = MFOA[cols]

# %%
ComValue

# %%
df3 = ComValue.loc[(MFOA['Weeks_done'] !='Zero')]
df3

# %%
df3.describe()

# %%
contingency_table = pd.crosstab(df3['VAIAK'], df3['STAI-change'])

# %%
from scipy.stats import chi2_contingency

chi2, p, dof, expected = chi2_contingency(contingency_table)

# Output the results
print(f"Chi-squared statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of freedom: {dof}")
print("Expected frequencies:")
print(expected)

# %%
correlation = df3['VAIAK'].corr(df3['STAI-change'])

# %%
# Check the correlation
if correlation == 0:
    print("There is no linear correlation between the two columns.")
else:
    print(f"There is a correlation of {correlation:.2f} between the two columns.")

# %%
from scipy.stats import pearsonr
correlation, p_value = pearsonr(df3['VAIAK'], df3['STAI-change'])

# %%
correlation_coefficient, p_value = pearsonr(df3['VAIAK'], df3['STAI-change'])

# Output the results
print(f"Pearson correlation coefficient (r): {correlation_coefficient}")
print(f"P-value: {p_value}")

# %%
if p_value < 0.05:  # You can adjust the significance level (alpha) as needed
    print(f"There is a statistically significant correlation of {correlation:.2f} between the two columns.")
else:
    print(f"There is no statistically significant correlation between the two columns.")
# Out:
# There is a statistically significant correlation of 0.76 between the two columns.

# %% [markdown]
# <div style="margin-top: -10px; background-color: #cbf3f0; padding: 10px; border-radius: 5px;">
# <h2 style="font-size: 24px; color: #2ec4b6;">SSCS further analysis</h2>
# </div>

# %%
url2 = 'https://raw.githubusercontent.com/lauricocha/Digital-Art-Making-Research-2024/main/MFoA-data-LG.csv'
df = pd.read_csv(url2)

# %%
cols = ['SSCS','STAI-change','Weeks_done']
ComValue = MFOA[cols]

# %%
ComValue

# %%
df4 = ComValue.loc[(MFOA['Weeks_done'] !='Zero')]
df4

# %%
contingency_table = pd.crosstab(df4['SSCS'], df4['STAI-change'])

# %%
from scipy.stats import chi2_contingency

chi2, p, dof, expected = chi2_contingency(contingency_table)

# Output the results
print(f"Chi-squared statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of freedom: {dof}")
print("Expected frequencies:")
print(expected)

# %%
correlation = df4['SSCS'].corr(df4['STAI-change'])

# %%
# Check the correlation
if correlation == 0:
    print("There is no linear correlation between the two columns.")
else:
    print(f"There is a correlation of {correlation:.2f} between the two columns.")

# %%
from scipy.stats import pearsonr
correlation, p_value = pearsonr(df4['SSCS'], df4['STAI-change'])

# %%
correlation_coefficient, p_value = pearsonr(df4['SSCS'], df4['STAI-change'])

# Output the results
print(f"Pearson correlation coefficient (r): {correlation_coefficient}")
print(f"P-value: {p_value}")

# %%
if p_value < 0.05:  # You can adjust the significance level (alpha) as needed
    print(f"There is a statistically significant correlation of {correlation:.2f} between the two columns.")
else:
    print(f"There is no statistically significant correlation between the two columns.")
# Out:
# There is a statistically significant correlation of 0.76 between the two columns.

# %%
df4.describe()

# %%
import numpy as np

# Example demographic and measurement data
demographic_data = {
    'Age': [52,23,20,72,24,28,57,32,26,28,50,51,61,25,19,31,56,31,53,24,25,23],
    'Gender': ['Female','Non-binary','Female','Female','Female','Male','Male','Female','Female','Female','Male','Female','Female','Male','Prefer not to say','Female','Male','Female','Male','Male','Female','Female'],
    'Ethnicity': ['HispLat','White','Asian','White','White','White','White','Asian','HispLat','Mixed','Mixed','White','Other','HispLat','HispLat','Asian','HispLat','White','Asian','White','White','White'],
}


measurement_data = [8,-2,1,-5,-12,-18,5,0,-6,-3,-10,-8,-12,-12,-2,-3,7]

# Calculate Mean (Mage), Standard Deviation (SD), and Range
mage = np.mean(np.abs(np.array(measurement_data)))
sd = np.std(measurement_data)
data_range = np.ptp(measurement_data)

print("Mean Absolute Gross Error (Mage):", mage)
print("Standard Deviation (SD):", sd)
print("Range:", data_range)

# %%
contingency_table = pd.crosstab(WeeklyV2['Initial_STAI'], WeeklyV2['Final_STAI'])

# %%
from scipy.stats import chi2_contingency

chi2, p, dof, expected = chi2_contingency(contingency_table)

# Output the results Figure 4A
print(f"Chi-squared statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of freedom: {dof}")
print("Expected frequencies:")
print(expected)

# %% [markdown]
# <div style="margin-top: -10px; background-color: #cbf3f0; padding: 10px; border-radius: 5px;">
# <h2 style="font-size: 24px; color: #2ec4b6;">Weekly variables histograms</h2>
# </div>

# %%
Weekly.hist(figsize = (10, 8), grid = False, color= '#7c1c5b');

# %%
import plotly.graph_objects as go
import pandas as pd
import plotly.io as pio
from IPython.display import Image

# Read the CSV file
url = 'https://raw.githubusercontent.com/lauricocha/Digital-Art-Making-Research-2024/main/MFoA-data-LG.csv'
df = pd.read_csv(url)

fig = go.Figure()

Anxiety_levels = ['low_anxiety', 'moderate_anxiety', 'high_anxiety']

for level in Anxiety_levels:
    fig.add_trace(go.Violin(x=df['Initial_Anxiety_level'][df['Initial_Anxiety_level'] == level],
                            y=df['STAI-change'][df['Initial_Anxiety_level'] == level],
                            name=level,
                            box_visible=True,
                            meanline_visible=True))
    
fig.update_layout(
    title="Effect of Intervention on Lowering Anxiety Across Various Initial Anxiety Levels",
    title_font=dict(size=22),
    height=600,  # Adjust the height
    width=1000,  # Adjust the width
    margin=dict(l=40, r=40, t=80, b=40)
)

fig.add_annotation(
    text="Chi-squared statistic: 13.18<br>p-value: 0.01041<br>Degrees of freedom: 4",
    x=0.2,  # Adjust the x and y values for proper positioning
    y=-22,
    showarrow=False,
    font=dict(size=16)  # Adjust the font size as needed
)

# %%
import plotly.graph_objects as go
import pandas as pd
import plotly.io as pio
from IPython.display import Image

# Read the CSV file
url = 'https://raw.githubusercontent.com/lauricocha/Digital-Art-Making-Research-2024/main/MFoA-data-LG.csv'
df = pd.read_csv(url)

fig = go.Figure()

Weeks_done = ['8 wks', '5-4 wks', '3-2 wks', '1 wk', '0 wks']

for week in Weeks_done:
    fig.add_trace(go.Violin(x=df['Weeks_done'][df['Weeks_done'] == week],
                            y=df['STAI-change'][df['Weeks_done'] == week],
                            name=week,
                            box_visible=True,
                            meanline_visible=True))
    
fig.update_layout(
    title="Effect of Intervention on Anxiety Reduction Over Weeks Completed",
    title_font=dict(size=22),
    height=600,  # Adjust the height
    width=1000,  # Adjust the width
    margin=dict(l=40, r=40, t=80, b=40)
)

fig.add_annotation(
    text="Chi-squared statistic: 74.14<br>p-value: 0.40828<br>Degrees of freedom: 72",
    x=2,  # Adjust the x and y values for proper positioning
    y=-24,
    showarrow=False,
    font=dict(size=16)  # Adjust the font size as needed
)
